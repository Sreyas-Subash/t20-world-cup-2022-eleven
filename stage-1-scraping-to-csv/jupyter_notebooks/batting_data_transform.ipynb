# %%
import pandas as pd
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

df = pd.read_csv('batting_data.csv')

# %%
df.head(20)
# Out:
#        match_id                  match          batting_team  \
# 0   T20I # 1823   Namibia Vs Sri Lanka               Namibia
# 1   T20I # 1823   Namibia Vs Sri Lanka               Namibia
# 2   T20I # 1823   Namibia Vs Sri Lanka               Namibia
# 3   T20I # 1823   Namibia Vs Sri Lanka               Namibia
# 4   T20I # 1823   Namibia Vs Sri Lanka               Namibia
# 5   T20I # 1823   Namibia Vs Sri Lanka               Namibia
# 6   T20I # 1823   Namibia Vs Sri Lanka               Namibia
# 7   T20I # 1823   Namibia Vs Sri Lanka               Namibia
# 8   T20I # 1823   Namibia Vs Sri Lanka             Sri Lanka
# 9   T20I # 1823   Namibia Vs Sri Lanka             Sri Lanka
# 10  T20I # 1823   Namibia Vs Sri Lanka             Sri Lanka
# 11  T20I # 1823   Namibia Vs Sri Lanka             Sri Lanka
# 12  T20I # 1823   Namibia Vs Sri Lanka             Sri Lanka
# 13  T20I # 1823   Namibia Vs Sri Lanka             Sri Lanka
# ...

# %%
df['out/not_out'] = df['out/not_out'].map(lambda x: 'not out' if x == 'not out' else 'out')
df
# Out:
#         match_id                        match          batting_team  \
# 0    T20I # 1823         Namibia Vs Sri Lanka               Namibia
# 1    T20I # 1823         Namibia Vs Sri Lanka               Namibia
# 2    T20I # 1823         Namibia Vs Sri Lanka               Namibia
# 3    T20I # 1823         Namibia Vs Sri Lanka               Namibia
# 4    T20I # 1823         Namibia Vs Sri Lanka               Namibia
# 5    T20I # 1823         Namibia Vs Sri Lanka               Namibia
# 6    T20I # 1823         Namibia Vs Sri Lanka               Namibia
# 7    T20I # 1823         Namibia Vs Sri Lanka               Namibia
# 8    T20I # 1823         Namibia Vs Sri Lanka             Sri Lanka
# 9    T20I # 1823         Namibia Vs Sri Lanka             Sri Lanka
# 10   T20I # 1823         Namibia Vs Sri Lanka             Sri Lanka
# 11   T20I # 1823         Namibia Vs Sri Lanka             Sri Lanka
# 12   T20I # 1823         Namibia Vs Sri Lanka             Sri Lanka
# ...

# %%
# df.groupby('batsman')['6s'].sum().sort_values(ascending=False)
# df.groupby('batsman')['runs'].mean().sort_values(ascending=False)
# df.groupby('batsman')['4s'].sum().sort_values(ascending=False)

# %%
unique_batsmen = df.batsman.unique().tolist()
unique_batsmen
# Out:
# ['Michael van Lingen',
#  'Divan la Cock',
#  'Jan Nicol Loftie-Eaton',
#  'Stephan Baard',
#  'Gerhard Erasmus',
#  'Jan Frylinck',
#  'David Wiese',
#  'JJ Smit',
#  'Pathum Nissanka',
#  'Kusal Mendis',
#  'Dhananjaya de Silva',
#  'Danushka Gunathilaka',
#  'Bhanuka Rajapaksa',
#  'Dasun Shanaka',
#  'Wanindu Hasaranga',
#  'Chamika Karunaratne',
#  'Pramod Madushan',
#  'Dushmantha Chameera',
#  'Maheesh Theekshana',
#  'Chirag Suri',
#  'Muhammad Waseem',
#  'Kashif Daud',
#  'Vriitya Aravind',
#  'Zawar Farid',
#  'Basil Hameed',
#  'Chundangapoyil Rizwan',
#  'Aayan Afzal Khan',
#  'Karthik Meiyappan',
#  'Junaid Siddique',
#  'Vikramjit Singh',
#  "Max O'Dowd",
#  'Bas de Leede',
#  'Colin Ackermann',
#  'Tom Cooper',
#  'Scott Edwards',
#  'Roelof van der Merwe',
#  'Tim Pringle',
#  'Logan van Beek',
#  'George Munsey',
#  'Michael Jones',
#  'Matthew Cross',
#  'Richie Berrington',
#  'Calum MacLeod',
#  'Michael Leask',
#  'Chris Greaves',
#  'Kyle Mayers',
# ...

# %%
for i in unique_batsmen:
    if i.replace(' ','').isalpha():
        continue
    else:
        print(i)
# Out:
# Jan Nicol Loftie-Eaton
# Max O'Dowd
# Naveen-ul-Haq

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 699 entries, 0 to 698
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   match_id          699 non-null    object
#  1   match             699 non-null    object
#  2   batting_team      699 non-null    object
#  3   batting_position  699 non-null    int64
#  4   batsman           699 non-null    object
#  5   out/not_out       699 non-null    object
#  6   runs              699 non-null    int64
#  7   balls             699 non-null    int64
#  8   4s                699 non-null    int64
#  9   6s                699 non-null    int64
#  10  strike_rate       699 non-null    object
# dtypes: int64(5), object(6)
# memory usage: 60.2+ KB

# %%
def is_number(input_string):
    try:
        float(input_string)
        return False
    except ValueError:
        return True

# %%
df[df['strike_rate'].map(is_number)]
# Out:
#         match_id                      match          batting_team  \
# 16   T20I # 1823       Namibia Vs Sri Lanka             Sri Lanka
# 27   T20I # 1825      Netherlands Vs U.A.E.  United Arab Emirates
# 160  T20I # 1835   Netherlands Vs Sri Lanka           Netherlands
# 281  T20I # 1843  Bangladesh Vs Netherlands           Netherlands
# 484  T20I # 1856   Afghanistan Vs Sri Lanka             Sri Lanka
# 593  T20I # 1864   Australia Vs Afghanistan           Afghanistan
# 602  T20I # 1867       England Vs Sri Lanka             Sri Lanka
# 643  T20I # 1872     Bangladesh Vs Pakistan              Pakistan
# 650  T20I # 1873          India Vs Zimbabwe                 India
# 672  T20I # 1877    New Zealand Vs Pakistan              Pakistan
# 679  T20I # 1878           England Vs India                 India
#
#      batting_position              batsman out/not_out  runs  balls  4s  6s  \
# 16                  9      Pramod Madushan         out     0      0   0   0
# ...

# %%
for col in df:
    print(col, df[col].nunique())
    print(df[col].unique())
# Out:
# match_id 42
# ['T20I # 1823' 'T20I # 1825' 'T20I # 1826' 'T20I # 1828' 'T20I # 1830'
#  'T20I # 1832' 'T20I # 1833' 'T20I # 1834' 'T20I # 1835' 'T20I # 1836'
#  'T20I # 1837' 'T20I # 1838' 'T20I # 1839' 'T20I # 1840' 'T20I # 1841'
#  'T20I # 1842' 'T20I # 1843' 'T20I # 1844' 'T20I # 1845' 'T20I # 1846'
#  'T20I # 1847' 'T20I # 1848' 'T20I # 1849' 'T20I # 1850' 'T20I # 1851'
#  'T20I # 1852' 'T20I # 1853' 'T20I # 1855' 'T20I # 1856' 'T20I # 1858'
#  'T20I # 1859' 'T20I # 1860' 'T20I # 1861' 'T20I # 1862' 'T20I # 1864'
#  'T20I # 1867' 'T20I # 1871' 'T20I # 1872' 'T20I # 1873' 'T20I # 1877'
#  'T20I # 1878' 'T20I # 1879']
# match 42
# ['Namibia Vs Sri Lanka' 'Netherlands Vs U.A.E.' 'Scotland Vs West Indies'
#  'Ireland Vs Zimbabwe' 'Namibia Vs Netherlands' 'Sri Lanka Vs U.A.E.'
#  'Ireland Vs Scotland' 'West Indies Vs Zimbabwe'
#  'Netherlands Vs Sri Lanka' 'Namibia Vs U.A.E.' 'Ireland Vs West Indies'
#  'Scotland Vs Zimbabwe' 'Australia Vs New Zealand'
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df
# Out:
#         match_id                        match          batting_team  \
# 0    T20I # 1823         Namibia Vs Sri Lanka               Namibia
# 1    T20I # 1823         Namibia Vs Sri Lanka               Namibia
# 2    T20I # 1823         Namibia Vs Sri Lanka               Namibia
# 3    T20I # 1823         Namibia Vs Sri Lanka               Namibia
# 4    T20I # 1823         Namibia Vs Sri Lanka               Namibia
# 5    T20I # 1823         Namibia Vs Sri Lanka               Namibia
# 6    T20I # 1823         Namibia Vs Sri Lanka               Namibia
# 7    T20I # 1823         Namibia Vs Sri Lanka               Namibia
# 8    T20I # 1823         Namibia Vs Sri Lanka             Sri Lanka
# 9    T20I # 1823         Namibia Vs Sri Lanka             Sri Lanka
# 10   T20I # 1823         Namibia Vs Sri Lanka             Sri Lanka
# 11   T20I # 1823         Namibia Vs Sri Lanka             Sri Lanka
# 12   T20I # 1823         Namibia Vs Sri Lanka             Sri Lanka
# ...

# %%
df['batting_team'].unique()
# Out:
# array(['Namibia', 'Sri Lanka', 'United Arab Emirates', 'Netherlands',
#        'Scotland', 'West Indies', 'Zimbabwe', 'Ireland', 'New Zealand',
#        'Australia', 'Afghanistan', 'England', 'Pakistan', 'India',
#        'Bangladesh', 'South Africa'], dtype=object)

# %%
df['batting_team'] = df['batting_team'].map(lambda x: x.replace('United Arab Emirates', 'U.A.E.'))

# %%
df
# Out:
#         match_id                        match  batting_team  batting_position  \
# 0    T20I # 1823         Namibia Vs Sri Lanka       Namibia                 1
# 1    T20I # 1823         Namibia Vs Sri Lanka       Namibia                 2
# 2    T20I # 1823         Namibia Vs Sri Lanka       Namibia                 3
# 3    T20I # 1823         Namibia Vs Sri Lanka       Namibia                 4
# 4    T20I # 1823         Namibia Vs Sri Lanka       Namibia                 5
# 5    T20I # 1823         Namibia Vs Sri Lanka       Namibia                 6
# 6    T20I # 1823         Namibia Vs Sri Lanka       Namibia                 7
# 7    T20I # 1823         Namibia Vs Sri Lanka       Namibia                 8
# 8    T20I # 1823         Namibia Vs Sri Lanka     Sri Lanka                 1
# 9    T20I # 1823         Namibia Vs Sri Lanka     Sri Lanka                 2
# 10   T20I # 1823         Namibia Vs Sri Lanka     Sri Lanka                 3
# ...

# %%
df.to_csv('batting_data_cleaned.csv',index=False)
