# %%
import pandas as pd

pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)

# %%
df = pd.read_csv('player_info.csv')

# %%
df
# Out:
#                      team                  player   batting_style  \
# 0                 Namibia      Michael van Lingen   Left hand Bat
# 1                 Namibia           Divan la Cock  Right hand Bat
# 2                 Namibia  Jan Nicol Loftie-Eaton   Left hand Bat
# 3                 Namibia           Stephan Baard  Right hand Bat
# 4                 Namibia         Gerhard Erasmus  Right hand Bat
# 5                 Namibia            Jan Frylinck   Left hand Bat
# 6                 Namibia             David Wiese  Right hand Bat
# 7                 Namibia                 JJ Smit  Right hand Bat
# 8                 Namibia              Zane Green   Left hand Bat
# 9                 Namibia         Bernard Scholtz  Right hand Bat
# 10                Namibia            Ben Shikongo  Right hand Bat
# 11              Sri Lanka         Pathum Nissanka  Right hand Bat
# 12              Sri Lanka            Kusal Mendis  Right hand Bat
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   team           216 non-null    object
#  1   player         216 non-null    object
#  2   batting_style  216 non-null    object
#  3   bowling_style  197 non-null    object
#  4   playing_role   216 non-null    object
#  5   image          214 non-null    object
# dtypes: object(6)
# memory usage: 10.2+ KB

# %%
for col in ['team','batting_style','bowling_style','playing_role']:
    print(col, ':', df[col].nunique())
    print(df[col].unique())
# Out:
# team : 16
# ['Namibia' 'Sri Lanka' 'United Arab Emirates' 'Netherlands' 'Scotland'
#  'West Indies' 'Zimbabwe' 'Ireland' 'New Zealand' 'Australia'
#  'Afghanistan' 'England' 'Pakistan' 'India' 'Bangladesh' 'South Africa']
# batting_style : 2
# ['Left hand Bat' 'Right hand Bat']
# bowling_style : 18
# ['Left arm Medium, Slow Left arm Orthodox' 'Legbreak'
#  'Right arm Medium, Legbreak' 'Right arm Medium fast' 'Right arm Offbreak'
#  'Left arm Fast medium' 'Left arm Medium fast' nan
#  'Slow Left arm Orthodox' 'Right arm Medium' 'Right arm Fast'
#  'Right arm Offbreak, Legbreak Googly' 'Legbreak Googly'
#  'Right arm Fast medium' 'Right arm Medium fast, Right arm Offbreak'
#  'Left arm Fast' 'Right arm Offbreak, Legbreak'
#  'Right arm Medium, Right arm Offbreak' 'Left arm Wrist spin']
# playing_role : 9
# ['Bowling Allrounder' 'Opening Batter' 'Batter' 'Allrounder'
#  'Wicketkeeper Batter' 'Bowler' 'Top order Batter' 'Middle order Batter'
#  'Batting Allrounder']
