# %%
from bs4 import BeautifulSoup

# %%
def custom_condition(tag):
    return tag.name == 'div' and 'info' in tag.get('class', []) and tag.text.startswith('Info')

# %%
html = """
<div class="info">Info 1</div>
<div class="info">Info 2</div>
<div class="info">Info 3</div>
<div class="other">Other 1</div>
<div class="other">Other 2</div>
"""

soup = BeautifulSoup(html, 'html.parser')

selected_elements = soup.find_all(custom_condition)
print(selected_elements)
# Out:
# [<div class="info">Info 1</div>, <div class="info">Info 2</div>, <div class="info">Info 3</div>]

# %%
for i in html.find_all('div'):
    print(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 for i in html.find_all('div'):
#       2     print(i)
#
# AttributeError: 'str' object has no attribute 'find_all'

# %%
html = """
<tr class=""><td class="ds-min-w-max ds-cursor-pointer ds-align-top"><div class="ds-text-tight-s ds-font-regular ds-flex ds-justify-center ds-items-center ds-w-7 ds-h-7 ds-rounded-full ds-border ds-border-ui-stroke ds-bg-fill-content-prime">2</div></td><td class="ds-min-w-max !ds-align-top"><div class="ds-cursor-pointer ds-pt-1"><div class="ds-text-tight-m ds-font-medium ds-flex ds-items-center"><div class="ds-text-typo">13/1<span class="ds-text-tight-s ds-font-regular ds-ml-1 ds-text-typo-mid2">(<!-- -->8 runs, 1 wkt<!-- -->)</span></div></div><div class="ds-text-typo"><div class="ds-text-compact-xs ds-pt-2 ds-mt-2"><b>Bowler:</b> Dushmantha Chameera</div><div class="ds-flex ds-my-3 ds--ml-1 ds-flex-wrap"><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>1</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-raw-red ds-text-raw-white ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-raw-white"><span>W</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>1</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-raw-green02 ds-text-raw-white ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-raw-white"><span>4</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>•</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>2</span></div></div></div></div><div class="ds-py-2 ds-mb-2"><div class="ds-p-1 ds-flex ds-bg-ui-fill-default-translucent ds-text-typo ds-items-center ds-max-w-max"><span class="ds-text-compact-xs ds-font-medium">Forecasted score: </span><div class="ds-flex ds-flex-wrap"><span class="ds-text-compact-xs ds-mx-1">NAM 151</span></div></div></div><div class="ds-text-tight-s ds-font-regular">RR: 6.50</div></div></div></td><td class="ds-min-w-max !ds-align-top"><div class="ds-cursor-pointer ds-pt-1"><div class="ds-text-tight-m ds-font-medium ds-flex ds-items-center"><div class="ds-text-typo">13/1<span class="ds-text-tight-s ds-font-regular ds-ml-1 ds-text-typo-mid2">(<!-- -->5 runs, 1 wkt<!-- -->)</span></div></div><div class="ds-text-typo"><div class="ds-text-compact-xs ds-pt-2 ds-mt-2"><b>Bowler:</b> David Wiese</div><div class="ds-flex ds-my-3 ds--ml-1 ds-flex-wrap"><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>•</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>2</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>2</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-raw-red ds-text-raw-white ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-raw-white"><span>W</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>1</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>•</span></div></div></div></div><div class="ds-py-2 ds-mb-2"><div class="ds-p-1 ds-flex ds-bg-fill-error ds-text-raw-white ds-items-center ds-max-w-max"><span class="ds-text-compact-xs ds-font-medium">Win probability: </span><div class="ds-flex ds-flex-wrap"><span class="ds-text-compact-xs ds-mx-1">SL 39.74%</span><i class="icon-trending-down ds-text-icon-inverse ds-ml-1" style="font-size: 20px;"></i><span class="ds-text-compact-xs ds-ml-1">-7.86%</span></div></div></div><div class="ds-text-tight-s ds-font-regular">RR: 6.50 • RRR:
                        8.38 • Runs req: 151 • Balls rem: 108</div></div></div></td></tr>
"""

# %%
soup = BeautifulSoup(html, 'lxml')
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <tr class="">
#    <td class="ds-min-w-max ds-cursor-pointer ds-align-top">
#     <div class="ds-text-tight-s ds-font-regular ds-flex ds-justify-center ds-items-center ds-w-7 ds-h-7 ds-rounded-full ds-border ds-border-ui-stroke ds-bg-fill-content-prime">
#      2
#     </div>
#    </td>
#    <td class="ds-min-w-max !ds-align-top">
#     <div class="ds-cursor-pointer ds-pt-1">
#      <div class="ds-text-tight-m ds-font-medium ds-flex ds-items-center">
#       <div class="ds-text-typo">
#        13/1
#        <span class="ds-text-tight-s ds-font-regular ds-ml-1 ds-text-typo-mid2">
#         (
#         <!-- -->
#         8 runs, 1 wkt
#         <!-- -->
#         )
#        </span>
#       </div>
#      </div>
#      <div class="ds-text-typo">
#       <div class="ds-text-compact-xs ds-pt-2 ds-mt-2">
#        <b>
#         Bowler:
#        </b>
#        Dushmantha Chameera
#       </div>
#       <div class="ds-flex ds-my-3 ds--ml-1 ds-flex-wrap">
# ...

# %%
tds = soup.find_all('td')
print(tds[0].prettify())
# Out:
# <td class="ds-min-w-max ds-cursor-pointer ds-align-top">
#  <div class="ds-text-tight-s ds-font-regular ds-flex ds-justify-center ds-items-center ds-w-7 ds-h-7 ds-rounded-full ds-border ds-border-ui-stroke ds-bg-fill-content-prime">
#   2
#  </div>
# </td>

# %%
print(tds[1].prettify())
# Out:
# <td class="ds-min-w-max !ds-align-top">
#  <div class="ds-cursor-pointer ds-pt-1">
#   <div class="ds-text-tight-m ds-font-medium ds-flex ds-items-center">
#    <div class="ds-text-typo">
#     13/1
#     <span class="ds-text-tight-s ds-font-regular ds-ml-1 ds-text-typo-mid2">
#      (
#      <!-- -->
#      8 runs, 1 wkt
#      <!-- -->
#      )
#     </span>
#    </div>
#   </div>
#   <div class="ds-text-typo">
#    <div class="ds-text-compact-xs ds-pt-2 ds-mt-2">
#     <b>
#      Bowler:
#     </b>
#     Dushmantha Chameera
#    </div>
#    <div class="ds-flex ds-my-3 ds--ml-1 ds-flex-wrap">
#     <div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5">
#      <div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1">
#       <div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo">
#        <span>
#         1
# ...

# %%
print(tds[2].prettify())
# Out:
# <td class="ds-min-w-max !ds-align-top">
#  <div class="ds-cursor-pointer ds-pt-1">
#   <div class="ds-text-tight-m ds-font-medium ds-flex ds-items-center">
#    <div class="ds-text-typo">
#     13/1
#     <span class="ds-text-tight-s ds-font-regular ds-ml-1 ds-text-typo-mid2">
#      (
#      <!-- -->
#      5 runs, 1 wkt
#      <!-- -->
#      )
#     </span>
#    </div>
#   </div>
#   <div class="ds-text-typo">
#    <div class="ds-text-compact-xs ds-pt-2 ds-mt-2">
#     <b>
#      Bowler:
#     </b>
#     David Wiese
#    </div>
#    <div class="ds-flex ds-my-3 ds--ml-1 ds-flex-wrap">
#     <div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5">
#      <div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1">
#       <div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo">
#        <span>
#         •
#        </span>
# ...

# %%
out1 = [td for td in tds]
for td in out1:
    if td:
        divs = td.find_all('div')
        out = [val.text for val in divs]
        print(out)
        print('******')
# Out:
# ['2']
# ******
# ['13/1(8 runs, 1 wkt)Bowler: Dushmantha Chameera1W14•2Forecasted score: NAM 151RR: 6.50', '13/1(8 runs, 1 wkt)', '13/1(8 runs, 1 wkt)', 'Bowler: Dushmantha Chameera1W14•2Forecasted score: NAM 151RR: 6.50', 'Bowler: Dushmantha Chameera', '1W14•2', '1', '1', '1', 'W', 'W', 'W', '1', '1', '1', '4', '4', '4', '•', '•', '•', '2', '2', '2', 'Forecasted score: NAM 151', 'Forecasted score: NAM 151', 'NAM 151', 'RR: 6.50']
# ******
# ...

# %%
out2 = [td.get_text() for td in tds]
out2
# Out:
# ['2',
#  '13/1(8 runs, 1 wkt)Bowler: Dushmantha Chameera1W14•2Forecasted score: NAM 151RR: 6.50',
#  '13/1(5 runs, 1 wkt)Bowler: David Wiese•22W1•Win probability: SL 39.74%-7.86%RR: 6.50 • RRR:\n                        8.38 • Runs req: 151 • Balls rem: 108']

# %%
from bs4 import BeautifulSoup

# %%
over1tr = '''
<tr class=""><td class="ds-min-w-max ds-cursor-pointer ds-align-top"><div class="ds-text-tight-s ds-font-regular ds-flex ds-justify-center ds-items-center ds-w-7 ds-h-7 ds-rounded-full ds-border ds-border-ui-stroke ds-bg-fill-content-prime">1</div></td><td class="ds-min-w-max !ds-align-top"><div class="ds-cursor-pointer ds-pt-1"><div class="ds-text-tight-m ds-font-medium ds-flex ds-items-center"><div class="ds-text-typo">5/0<span class="ds-text-tight-s ds-font-regular ds-ml-1 ds-text-typo-mid2">(<!-- -->5 runs, 0 wkt<!-- -->)</span></div></div><div class="ds-text-typo"><div class="ds-text-compact-xs ds-pt-2 ds-mt-2"><b>Bowler<!-- -->:</b> <!-- -->Maheesh Theekshana</div><div class="ds-flex ds-my-3 ds--ml-1 ds-flex-wrap"><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>•</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>•</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>1</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>1</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>2</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>1w</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>•</span></div></div></div></div><div class="ds-py-2 ds-mb-2"><div class="ds-p-1 ds-flex ds-bg-ui-fill-default-translucent ds-text-typo ds-items-center ds-max-w-max"><span class="ds-text-compact-xs ds-font-medium">Forecasted score: </span><div class="ds-flex ds-flex-wrap"><span class="ds-text-compact-xs ds-mx-1">NAM<!-- --> <!-- -->151</span></div></div></div><div class="ds-text-tight-s ds-font-regular">RR<!-- -->: <!-- -->5.00</div></div></div></td><td class="ds-min-w-max !ds-align-top"><div class="ds-cursor-pointer ds-pt-1"><div class="ds-text-tight-m ds-font-medium ds-flex ds-items-center"><div class="ds-text-typo">8/0<span class="ds-text-tight-s ds-font-regular ds-ml-1 ds-text-typo-mid2">(<!-- -->8 runs, 0 wkt<!-- -->)</span></div></div><div class="ds-text-typo"><div class="ds-text-compact-xs ds-pt-2 ds-mt-2"><b>Bowler<!-- -->:</b> <!-- -->Gerhard Erasmus</div><div class="ds-flex ds-my-3 ds--ml-1 ds-flex-wrap"><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-raw-green02 ds-text-raw-white ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-raw-white"><span>4</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>1</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>1</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>•</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>1</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>1</span></div></div></div></div><div class="ds-py-2 ds-mb-2"><div class="ds-p-1 ds-flex ds-bg-ui-fill-default-translucent ds-text-typo ds-items-center ds-max-w-max"><span class="ds-text-compact-xs ds-font-medium">Win probability: </span><div class="ds-flex ds-flex-wrap"><span class="ds-text-compact-xs ds-mx-1">SL<!-- --> <!-- -->47.6<!-- -->%</span></div></div></div><div class="ds-text-tight-s ds-font-regular">RR<!-- -->: <!-- -->8.00<!-- --> • RRR:
                        8.21<!-- --> • Runs req: 156<!-- --> • Balls rem: 114</div></div></div></td></tr>
'''

# %%
over2tr = '''
<tr class=""><td class="ds-min-w-max ds-cursor-pointer ds-align-top"><div class="ds-text-tight-s ds-font-regular ds-flex ds-justify-center ds-items-center ds-w-7 ds-h-7 ds-rounded-full ds-border ds-border-ui-stroke ds-bg-fill-content-prime">2</div></td><td class="ds-min-w-max !ds-align-top"><div class="ds-cursor-pointer ds-pt-1"><div class="ds-text-tight-m ds-font-medium ds-flex ds-items-center"><div class="ds-text-typo">13/1<span class="ds-text-tight-s ds-font-regular ds-ml-1 ds-text-typo-mid2">(<!-- -->8 runs, 1 wkt<!-- -->)</span></div></div><div class="ds-text-typo"><div class="ds-text-compact-xs ds-pt-2 ds-mt-2"><b>Bowler:</b> Dushmantha Chameera</div><div class="ds-flex ds-my-3 ds--ml-1 ds-flex-wrap"><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>1</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-raw-red ds-text-raw-white ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-raw-white"><span>W</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>1</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-raw-green02 ds-text-raw-white ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-raw-white"><span>4</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>•</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>2</span></div></div></div></div><div class="ds-py-2 ds-mb-2"><div class="ds-p-1 ds-flex ds-bg-ui-fill-default-translucent ds-text-typo ds-items-center ds-max-w-max"><span class="ds-text-compact-xs ds-font-medium">Forecasted score: </span><div class="ds-flex ds-flex-wrap"><span class="ds-text-compact-xs ds-mx-1">NAM 151</span></div></div></div><div class="ds-text-tight-s ds-font-regular">RR: 6.50</div></div></div></td><td class="ds-min-w-max !ds-align-top"><div class="ds-cursor-pointer ds-pt-1"><div class="ds-text-tight-m ds-font-medium ds-flex ds-items-center"><div class="ds-text-typo">13/1<span class="ds-text-tight-s ds-font-regular ds-ml-1 ds-text-typo-mid2">(<!-- -->5 runs, 1 wkt<!-- -->)</span></div></div><div class="ds-text-typo"><div class="ds-text-compact-xs ds-pt-2 ds-mt-2"><b>Bowler:</b> David Wiese</div><div class="ds-flex ds-my-3 ds--ml-1 ds-flex-wrap"><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>•</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>2</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>2</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-raw-red ds-text-raw-white ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-raw-white"><span>W</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>1</span></div></div></div><div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5"><div class="ds-flex ds-items-center ds-justify-center ds-rounded ds-overflow-hidden ds-bg-ui-fill-default-translucent ds-text-typo ds-mb-1 ds-mx-1"><div class="ds-text-tight-m ds-font-bold ds-flex ds-items-center ds-justify-center ds-text-center ds-w-8 ds-h-8 ds-text-typo"><span>•</span></div></div></div></div><div class="ds-py-2 ds-mb-2"><div class="ds-p-1 ds-flex ds-bg-fill-error ds-text-raw-white ds-items-center ds-max-w-max"><span class="ds-text-compact-xs ds-font-medium">Win probability: </span><div class="ds-flex ds-flex-wrap"><span class="ds-text-compact-xs ds-mx-1">SL 39.74%</span><i class="icon-trending-down ds-text-icon-inverse ds-ml-1" style="font-size: 20px;"></i><span class="ds-text-compact-xs ds-ml-1">-7.86%</span></div></div></div><div class="ds-text-tight-s ds-font-regular">RR: 6.50 • RRR:
                        8.38 • Runs req: 151 • Balls rem: 108</div></div></div></td></tr>
'''

# %%
soup1 = BeautifulSoup(over2tr, 'html.parser')
print(soup1.prettify())
# Out:
# <tr class="">
#  <td class="ds-min-w-max ds-cursor-pointer ds-align-top">
#   <div class="ds-text-tight-s ds-font-regular ds-flex ds-justify-center ds-items-center ds-w-7 ds-h-7 ds-rounded-full ds-border ds-border-ui-stroke ds-bg-fill-content-prime">
#    2
#   </div>
#  </td>
#  <td class="ds-min-w-max !ds-align-top">
#   <div class="ds-cursor-pointer ds-pt-1">
#    <div class="ds-text-tight-m ds-font-medium ds-flex ds-items-center">
#     <div class="ds-text-typo">
#      13/1
#      <span class="ds-text-tight-s ds-font-regular ds-ml-1 ds-text-typo-mid2">
#       (
#       <!-- -->
#       8 runs, 1 wkt
#       <!-- -->
#       )
#      </span>
#     </div>
#    </div>
#    <div class="ds-text-typo">
#     <div class="ds-text-compact-xs ds-pt-2 ds-mt-2">
#      <b>
#       Bowler:
#      </b>
#      Dushmantha Chameera
#     </div>
#     <div class="ds-flex ds-my-3 ds--ml-1 ds-flex-wrap">
#      <div class="ds-flex ds-flex-col ds-items-center ds-mb-1.5">
# ...

# %%
tds = soup1.find_all('td')

# %%
parent_div = tds[1].div

# %%
k = {}
i = 1
for child in parent_div.children:
    k[i] = child
    i = i + 1
print(k[2].find('div').text)
# Out:
# Bowler: Dushmantha Chameera
